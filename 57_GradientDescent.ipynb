# %%
from sklearn.datasets import make_regression  # make_regression() is a function from sklearn.datasets.
# It generates data that follows a linear regression relationship
import numpy as np

# %%
X,y = make_regression(n_samples = 4, n_features=1,n_informative=1,noise=80,random_state = 13)   
# n_samples = 4 ->This means-Create 4 data points (rows).

# n_features = 1 -> This means-Each sample has 1 input feature (1 column).
# n_informative = 1 -> This means - Out of all features, 1 feature actually affects the output.
# n_informative = 1 -> This means - Out of all features, 1 feature actually affects the output.
#

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
# Lets apply OLS ->
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = "red")

# %%
# Lerts apply Gradient Descent assuming slope is constant m = 78.35
# and let's assume the starting value for intercept b = 0 . ab yehi goal hain ki b ka value 26.15 tak pohchana hain 
y_pred = ((78.35 * X ) + 0).reshape(4)   # This line calculates the predicted values (y_pred) using the equation of a linear regression model.

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label="OLS") 
plt.plot(X,y_pred,color="#00a56a",label="b = 0")
plt.legend()
plt.show()

# %% [markdown]
# Ab gradient descent apply karna hain and red line move towards red line because hame intercept b = 26.15 karna hain.

# %%
m = 78.35
b = 0
loss_slope = -2 *np.sum(y - m*X.ravel() - b)   # ravel() converts it into a one-dimensional array. 
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
# Lets take learning rate = 0.1
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
# Calculating the new intercept ->
b = b - step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="black",label="OLS")
plt.plot(X,y_pred1,color="#00a56a",label="b = {}".format(b)) # this line shows what the regression line looks like after updating b.
plt.plot(X,y_pred,color="#A3E4D7",label="b = 0")
plt.legend()
plt.show()

# %%
# Iteration 2 -> 
m = 78.35
b = b 
loss_slope = -2 *np.sum(y - m*X.ravel() - b)   # ravel() converts it into a one-dimensional array. 
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
# Calculating the new intercept ->
b = b - step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2 = ((78.35 * X) + b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="black",label="OLS")
plt.plot(X,y_pred1,color="#00a56a",label="b = {}".format(b)) # this line shows what the regression line looks like after updating b.
plt.plot(X,y_pred,color="#A3E4D7",label="b = 0")
plt.plot(X,y_pred2,color="yellow",label= "b= {}".format(b))
plt.legend()
plt.show()

# %%
# Iteration 3 ->
m = 78.35
b = b 
loss_slope = -2 *np.sum(y - m*X.ravel() - b)   # ravel() converts it into a one-dimensional array. 
loss_slope
# Out:
# np.float64(-8.371105363283675)

# %%
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-0.8371105363283675)

# %%
# Calculating the new intercept ->
b = b - step_size
b
# Out:
# np.float64(25.95042662617943)

# %%
y_pred3 = ((78.35 * X) + b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="black",label="OLS")
plt.plot(X,y_pred1,color="#00a56a",label="b = {}".format(b)) # this line shows what the regression line looks like after updating b.
plt.plot(X,y_pred2,color="yellow",label= "b= {}".format(b))
plt.plot(X,y_pred3,color="#00a65a",label= "b= {}".format(b))
plt.plot(X,y_pred,color="#A3E4D7",label="b = 0")
plt.legend()
plt.show()

# %%
m = 78.35
b = b 
loss_slope = -2 *np.sum(y - m*X.ravel() - b)   # ravel() converts it into a one-dimensional array. 
loss_slope
# Out:
# np.float64(-1.674221072656735)

# %%
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-0.16742210726567353)

# %%
# Calculating the new intercept ->
b = b - step_size
b
# Out:
# np.float64(26.1178487334451)

# %%
y_pred4 = ((78.35 * X) + b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="black",label="OLS")
plt.plot(X,y_pred1,color="#00a56a",label="b = {}".format(b)) # this line shows what the regression line looks like after updating b.
plt.plot(X,y_pred2,color="yellow",label= "b= {}".format(b))
plt.plot(X,y_pred3,color="#00a65a",label= "b= {}".format(b))
plt.plot(X,y_pred4,color="pink",label= "b= {}".format(b))
plt.plot(X,y_pred,color="#A3E4D7",label="b = 0")
plt.legend()
plt.show()

# %% [markdown]
# # Now b = -100

# %%
b = -100
lr = 78.35
lr = 0.1

epochs = 10

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b )
    b = b - (lr * loss_slope)

    y_pred = m * X + b
    plt.plot(X,y_pred)

    plt.scatter(X,y)

# %% [markdown]
# # If learing rate bhot chota ho toh ->

# %%
b = -100
lr = 78.35
lr = 0.01

epochs = 100

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b )
    b = b - (lr * loss_slope)

    y_pred = m * X + b
    plt.plot(X,y_pred)

    plt.scatter(X,y)
